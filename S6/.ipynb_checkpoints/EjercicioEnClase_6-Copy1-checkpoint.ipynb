# %% [markdown]
# # Ejercicio en clase 6
#
# ##### Dataset de Peajes (Exploración, Limpieza, Combinación, visualización en mapa)
#
# https://www.kaggle.com/datasets/martinaltamar/historico-peajes-colombia-trafico-y-recaudo
#
# https://geoportal.dane.gov.co/servicios/descarga-y-metadatos/datos-geoestadisticos/?cod=4
#
#
# Usando la información de los siguientes enlaces:
#
# Dataset de Kaggle: Historico Peajes Colombia - Tráfico y Recaudo
# Datos Geoespaciales del DANE: Descarga y Metadatos - Datos Geoestadísticos de Colombia
#
# Tu tarea es crear un mapa interactivo donde se puedan visualizar los peajes registrados en Colombia. Utiliza los datos proporcionados en el dataset de Kaggle para obtener la información relevante sobre los peajes, como su ubicación geoespacial y otros atributos pertinentes. Luego, utiliza los datos geoespaciales del DANE para representar correctamente la geografía de Colombia en el mapa.
#
# Puedes hacer uso de la biblioteca Folium en Python para la visualización del mapa interactivo. Asegúrate de incluir marcadores para cada peaje con información relevante que permita a los usuarios explorar los detalles de cada ubicación de peaje.
#
# Además, considera utilizar colores o tamaños de marcadores para resaltar características específicas de los peajes, como la tarifa

# %% [markdown]
# ## Usando Folium

# %% [markdown]
# ##### 💡 Recuerde instalar la librería
#
# ### Referencias
#
# - https://github.com/python-visualization/folium
# - https://python-visualization.github.io/folium/
# - https://nbviewer.org/github/python-visualization/folium/tree/main/examples/

# %%
import pandas as pd
import folium

# Crear un DataFrame con las coordenadas geográficas de las ciudades principales de Colombia
data = {
    'City': ['Bogotá', 'Medellín', 'Cali', 'Barranquilla', 'Cartagena'],
    'Latitude': [4.6482837, 6.2518402, 3.42158, 10.963889, 10.39972],
    'Longitude': [-74.2478935, -75.5635918, -76.5205, -74.796389, -75.51444]
}
df = pd.DataFrame(data)

# Crear un mapa de Folium centrado en Colombia
m = folium.Map(location=[4.6482837, -74.2478935], zoom_start=6)

# Agregar marcadores para cada ciudad al mapa
for index, row in df.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=row['City'],
        icon=folium.Icon(icon='star')  # Puedes cambiar el icono aquí
    ).add_to(m)

# Mostrar el mapa
m.save('map_colombia_cities.html')  # Guardar el mapa en un archivo HTML

# Mostrar el mapa interactivo en el notebook
display(m)

# m.show_in_browser()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cc83c590303829c80ff150138a71fae8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cc83c590303829c80ff150138a71fae8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cc83c590303829c80ff150138a71fae8 = L.map(
#                 &quot;map_cc83c590303829c80ff150138a71fae8&quot;,
#                 {
#                     center: [4.6482837, -74.2478935],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8b969827e4759edba9992fc78f0e0eb4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cc83c590303829c80ff150138a71fae8);
#
#
#             var marker_40a9ab7d3a6d074ec8d0b75e05e72641 = L.marker(
#                 [4.6482837, -74.2478935],
#                 {}
#             ).addTo(map_cc83c590303829c80ff150138a71fae8);
#
#
#             var icon_60448e2758999bd08dc3d6ce310d9c6f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_40a9ab7d3a6d074ec8d0b75e05e72641.setIcon(icon_60448e2758999bd08dc3d6ce310d9c6f);
#
#
#         var popup_eff34310c368f4b78b0d1a7423d9e7cb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_299cce7b10b77cb02b92c98e08ad0850 = $(`&lt;div id=&quot;html_299cce7b10b77cb02b92c98e08ad0850&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bogotá&lt;/div&gt;`)[0];
#                 popup_eff34310c368f4b78b0d1a7423d9e7cb.setContent(html_299cce7b10b77cb02b92c98e08ad0850);
#
#
#
#         marker_40a9ab7d3a6d074ec8d0b75e05e72641.bindPopup(popup_eff34310c368f4b78b0d1a7423d9e7cb)
#         ;
#
#
#
#
#             var marker_2d87adc0aca2aaff062ec236421915d5 = L.marker(
#                 [6.2518402, -75.5635918],
#                 {}
#             ).addTo(map_cc83c590303829c80ff150138a71fae8);
#
#
#             var icon_7209d0f37e28b1423c6c7cafb7c848d0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2d87adc0aca2aaff062ec236421915d5.setIcon(icon_7209d0f37e28b1423c6c7cafb7c848d0);
#
#
#         var popup_bfe0560cfa131bc2a5cba07d4113f9ff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2ae04cf9755cc2dbf6dc298eb64dc7c4 = $(`&lt;div id=&quot;html_2ae04cf9755cc2dbf6dc298eb64dc7c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Medellín&lt;/div&gt;`)[0];
#                 popup_bfe0560cfa131bc2a5cba07d4113f9ff.setContent(html_2ae04cf9755cc2dbf6dc298eb64dc7c4);
#
#
#
#         marker_2d87adc0aca2aaff062ec236421915d5.bindPopup(popup_bfe0560cfa131bc2a5cba07d4113f9ff)
#         ;
#
#
#
#
#             var marker_45a2b4ca2546fb94730b1ff599176a92 = L.marker(
#                 [3.42158, -76.5205],
#                 {}
#             ).addTo(map_cc83c590303829c80ff150138a71fae8);
#
#
#             var icon_8a9cb96f5a78b4c837dd7f2eaa2846e7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_45a2b4ca2546fb94730b1ff599176a92.setIcon(icon_8a9cb96f5a78b4c837dd7f2eaa2846e7);
#
#
#         var popup_d71a95bb2fb85e493f41582d3ba534e1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bab165255721a3c23c4a66820c208eee = $(`&lt;div id=&quot;html_bab165255721a3c23c4a66820c208eee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cali&lt;/div&gt;`)[0];
#                 popup_d71a95bb2fb85e493f41582d3ba534e1.setContent(html_bab165255721a3c23c4a66820c208eee);
#
#
#
#         marker_45a2b4ca2546fb94730b1ff599176a92.bindPopup(popup_d71a95bb2fb85e493f41582d3ba534e1)
#         ;
#
#
#
#
#             var marker_2d8169b3048016671b2f2a90508b4423 = L.marker(
#                 [10.963889, -74.796389],
#                 {}
#             ).addTo(map_cc83c590303829c80ff150138a71fae8);
#
#
#             var icon_2e2f6585b95029f1075394441877ec23 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;:

# %% [markdown]
# # Mapa con marcadores:

# %%
import folium

# Crear un mapa centrado en una ubicación específica
mapa = folium.Map(location=[4.60971, -74.08175], zoom_start=10)

# Agregar marcadores en diferentes ubicaciones
folium.Marker([4.60971, -74.08175], popup='Bogotá').add_to(mapa)
folium.Marker([6.24420, -75.58120], popup='Medellín').add_to(mapa)
folium.Marker([10.39105, -75.47971], popup='Cartagena').add_to(mapa)

# Mostrar el mapa interactivo
mapa.save('mapa_marcadores.html')

# Mostrar el mapa interactivo en el notebook
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_51b8e4272e3c7e5cbdc064cbaaa8e05c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_51b8e4272e3c7e5cbdc064cbaaa8e05c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_51b8e4272e3c7e5cbdc064cbaaa8e05c = L.map(
#                 &quot;map_51b8e4272e3c7e5cbdc064cbaaa8e05c&quot;,
#                 {
#                     center: [4.60971, -74.08175],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2d78ed0dd509504c6ea5e421f84e43fc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_51b8e4272e3c7e5cbdc064cbaaa8e05c);
#
#
#             var marker_cb015c4f1f5a15036b0016a80ace5df5 = L.marker(
#                 [4.60971, -74.08175],
#                 {}
#             ).addTo(map_51b8e4272e3c7e5cbdc064cbaaa8e05c);
#
#
#         var popup_f55a6f2630711893d564dbb57d8f01ca = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dc179b9b19838e7ea0398a2fcd0c3799 = $(`&lt;div id=&quot;html_dc179b9b19838e7ea0398a2fcd0c3799&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bogotá&lt;/div&gt;`)[0];
#                 popup_f55a6f2630711893d564dbb57d8f01ca.setContent(html_dc179b9b19838e7ea0398a2fcd0c3799);
#
#
#
#         marker_cb015c4f1f5a15036b0016a80ace5df5.bindPopup(popup_f55a6f2630711893d564dbb57d8f01ca)
#         ;
#
#
#
#
#             var marker_1f14fe41c2e25cfa9403a1541bb5b2b6 = L.marker(
#                 [6.2442, -75.5812],
#                 {}
#             ).addTo(map_51b8e4272e3c7e5cbdc064cbaaa8e05c);
#
#
#         var popup_28c25a827320feb3f211566c4df80166 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_930c0086a96653afabf16fb2fc963450 = $(`&lt;div id=&quot;html_930c0086a96653afabf16fb2fc963450&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Medellín&lt;/div&gt;`)[0];
#                 popup_28c25a827320feb3f211566c4df80166.setContent(html_930c0086a96653afabf16fb2fc963450);
#
#
#
#         marker_1f14fe41c2e25cfa9403a1541bb5b2b6.bindPopup(popup_28c25a827320feb3f211566c4df80166)
#         ;
#
#
#
#
#             var marker_b438eb80ffadcb4bcc72f30335765032 = L.marker(
#                 [10.39105, -75.47971],
#                 {}
#             ).addTo(map_51b8e4272e3c7e5cbdc064cbaaa8e05c);
#
#
#         var popup_d36407446ad8e46be333a1d20b919255 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_809b691f3b3b0fedd6acf0fa33723fb6 = $(`&lt;div id=&quot;html_809b691f3b3b0fedd6acf0fa33723fb6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cartagena&lt;/div&gt;`)[0];
#                 popup_d36407446ad8e46be333a1d20b919255.setContent(html_809b691f3b3b0fedd6acf0fa33723fb6);
#
#
#
#         marker_b438eb80ffadcb4bcc72f30335765032.bindPopup(popup_d36407446ad8e46be333a1d20b919255)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Mapa de calor:

# %%
import folium
from folium.plugins import HeatMap

# Crear un mapa centrado en una ubicación específica
mapa = folium.Map(location=[4.60971, -74.08175], zoom_start=10)

# Datos de ejemplo con ubicaciones y pesos
datos = [[4.60971, -74.08175, 10], [6.24420, -75.58120, 5], [10.39105, -75.47971, 15]]

# Agregar el mapa de calor con los datos
HeatMap(datos).add_to(mapa)

# Mostrar el mapa interactivo
mapa.save('mapa_calor.html')

# Mostrar el mapa interactivo en el notebook
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dbeb53b27cca58839e295a9093497be7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dbeb53b27cca58839e295a9093497be7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dbeb53b27cca58839e295a9093497be7 = L.map(
#                 &quot;map_dbeb53b27cca58839e295a9093497be7&quot;,
#                 {
#                     center: [4.60971, -74.08175],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aa7de71cf983ddfe75645e8ab1c1119a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_dbeb53b27cca58839e295a9093497be7);
#
#
#             var heat_map_462a7866d453b7656c3893d46865272d = L.heatLayer(
#                 [[4.60971, -74.08175, 10], [6.2442, -75.5812, 5], [10.39105, -75.47971, 15]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 25}
#             ).addTo(map_dbeb53b27cca58839e295a9093497be7);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Mapa con polígonos:

# %%
import folium

# Crear un mapa centrado en una ubicación específica
mapa = folium.Map(location=[4.60971, -74.08175], zoom_start=10)

# Datos de ejemplo con coordenadas de los vértices de un polígono
vertices = [[4.5, -74.0], [4.7, -74.0], [4.7, -73.8], [4.5, -73.8]]

# Agregar un polígono al mapa
folium.Polygon(locations=vertices, color='blue', fill=True, fill_color='blue').add_to(mapa)

# Mostrar el mapa interactivo
mapa.save('mapa_poligono.html')

# Mostrar el mapa interactivo en el notebook
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6530f61f975d8fd8740ad91e73445a7b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6530f61f975d8fd8740ad91e73445a7b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6530f61f975d8fd8740ad91e73445a7b = L.map(
#                 &quot;map_6530f61f975d8fd8740ad91e73445a7b&quot;,
#                 {
#                     center: [4.60971, -74.08175],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_099c671dd636809dee92526c65e29d58 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6530f61f975d8fd8740ad91e73445a7b);
#
#
#             var polygon_225c5ad879f44b44ac74832c67652624 = L.polygon(
#                 [[4.5, -74.0], [4.7, -74.0], [4.7, -73.8], [4.5, -73.8]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6530f61f975d8fd8740ad91e73445a7b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# Crear un mapa centrado en una ubicación específica
mapa = folium.Map(location=[4.60971, -74.08175], zoom_start=10)

# Agregar marcadores en diferentes ubicaciones con contenido personalizado para el popup
folium.Marker([4.60971, -74.08175], popup='Bogotá - Capital de Colombia').add_to(mapa)
folium.Marker([6.24420, -75.58120], popup='Medellín - Ciudad de la eterna primavera').add_to(mapa)
folium.Marker([10.39105, -75.47971], popup='Cartagena - Ciudad amurallada').add_to(mapa)

# Mostrar el mapa interactivo en el notebook
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d49390b3d8d17265170cd2dc25825b93 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d49390b3d8d17265170cd2dc25825b93&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d49390b3d8d17265170cd2dc25825b93 = L.map(
#                 &quot;map_d49390b3d8d17265170cd2dc25825b93&quot;,
#                 {
#                     center: [4.60971, -74.08175],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a85bc9a02ab97c93828574a455dd1a1b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d49390b3d8d17265170cd2dc25825b93);
#
#
#             var marker_c649d2a56e3cbf24452132fa8212e674 = L.marker(
#                 [4.60971, -74.08175],
#                 {}
#             ).addTo(map_d49390b3d8d17265170cd2dc25825b93);
#
#
#         var popup_5fcfb1bb0cbdbf4e2cfbf2de42ab685c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_00ae8fb539e8ba9e41bac084fad80b56 = $(`&lt;div id=&quot;html_00ae8fb539e8ba9e41bac084fad80b56&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bogotá - Capital de Colombia&lt;/div&gt;`)[0];
#                 popup_5fcfb1bb0cbdbf4e2cfbf2de42ab685c.setContent(html_00ae8fb539e8ba9e41bac084fad80b56);
#
#
#
#         marker_c649d2a56e3cbf24452132fa8212e674.bindPopup(popup_5fcfb1bb0cbdbf4e2cfbf2de42ab685c)
#         ;
#
#
#
#
#             var marker_6b4db1d0590f8a55f385eb6338106ff1 = L.marker(
#                 [6.2442, -75.5812],
#                 {}
#             ).addTo(map_d49390b3d8d17265170cd2dc25825b93);
#
#
#         var popup_2619cb8dc58a2c4e38085ce3b674dce5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_566cbd57fbd081b96ff5c336949b45a0 = $(`&lt;div id=&quot;html_566cbd57fbd081b96ff5c336949b45a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Medellín - Ciudad de la eterna primavera&lt;/div&gt;`)[0];
#                 popup_2619cb8dc58a2c4e38085ce3b674dce5.setContent(html_566cbd57fbd081b96ff5c336949b45a0);
#
#
#
#         marker_6b4db1d0590f8a55f385eb6338106ff1.bindPopup(popup_2619cb8dc58a2c4e38085ce3b674dce5)
#         ;
#
#
#
#
#             var marker_94350168221922bf30f5317d64b48e36 = L.marker(
#                 [10.39105, -75.47971],
#                 {}
#             ).addTo(map_d49390b3d8d17265170cd2dc25825b93);
#
#
#         var popup_b7ad00d2bf4dc2c441911dbdc3891d18 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8bae5e580b456bc3da222a206caa2263 = $(`&lt;div id=&quot;html_8bae5e580b456bc3da222a206caa2263&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cartagena - Ciudad amurallada&lt;/div&gt;`)[0];
#                 popup_b7ad00d2bf4dc2c441911dbdc3891d18.setContent(html_8bae5e580b456bc3da222a206caa2263);
#
#
#
#         marker_94350168221922bf30f5317d64b48e36.bindPopup(popup_b7ad00d2bf4dc2c441911dbdc3891d18)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# Crear un mapa centrado en una ubicación específica
mapa = folium.Map(location=[4.60971, -74.08175], zoom_start=10)

# Agregar un marcador con un icono predefinido (en este caso, un ícono de estrella)
folium.Marker([4.60971, -74.08175], popup='Bogotá', icon=folium.Icon(icon='star')).add_to(mapa)

# Mostrar el mapa interactivo en el notebook
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6b7f0fd290c3f0dd67cdd88d33ef2c73 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6b7f0fd290c3f0dd67cdd88d33ef2c73&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6b7f0fd290c3f0dd67cdd88d33ef2c73 = L.map(
#                 &quot;map_6b7f0fd290c3f0dd67cdd88d33ef2c73&quot;,
#                 {
#                     center: [4.60971, -74.08175],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_31c86e67e40248f0364c4a20b720a5e6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6b7f0fd290c3f0dd67cdd88d33ef2c73);
#
#
#             var marker_be2dbc5d0d0be8e4ef39fc4804c2021c = L.marker(
#                 [4.60971, -74.08175],
#                 {}
#             ).addTo(map_6b7f0fd290c3f0dd67cdd88d33ef2c73);
#
#
#             var icon_bc3a7b38538b89aa3bce3a6b9a0a8124 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_be2dbc5d0d0be8e4ef39fc4804c2021c.setIcon(icon_bc3a7b38538b89aa3bce3a6b9a0a8124);
#
#
#         var popup_d860000e6a83a31a8a60e3ebfa411dd1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_26110989baa24e8b6fa324139acce3d8 = $(`&lt;div id=&quot;html_26110989baa24e8b6fa324139acce3d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bogotá&lt;/div&gt;`)[0];
#                 popup_d860000e6a83a31a8a60e3ebfa411dd1.setContent(html_26110989baa24e8b6fa324139acce3d8);
#
#
#
#         marker_be2dbc5d0d0be8e4ef39fc4804c2021c.bindPopup(popup_d860000e6a83a31a8a60e3ebfa411dd1)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# Crear un mapa centrado en una ubicación específica
mapa = folium.Map(location=[4.60971, -74.08175], zoom_start=10)

# Definir la ruta del archivo de imagen del icono personalizado
ruta_icono_personalizado = 'dolar.png'

# Crear un objeto Icon con el icono personalizado
icono_personalizado = folium.CustomIcon(icon_image=ruta_icono_personalizado, icon_size=(30, 30))

# Agregar un marcador con el icono personalizado
folium.Marker([4.60971, -74.08175], popup='Bogotá', icon=icono_personalizado).add_to(mapa)

# Mostrar el mapa interactivo en el notebook
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b217835ce5e998ebf72c22887f30523e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b217835ce5e998ebf72c22887f30523e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b217835ce5e998ebf72c22887f30523e = L.map(
#                 &quot;map_b217835ce5e998ebf72c22887f30523e&quot;,
#                 {
#                     center: [4.60971, -74.08175],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a32d46bd95be3bff44f5e9f36bf558c6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b217835ce5e998ebf72c22887f30523e);
#
#
#             var marker_4f051be6cf494c21591638fb422383e0 = L.marker(
#                 [4.60971, -74.08175],
#                 {}
#             ).addTo(map_b217835ce5e998ebf72c22887f30523e);
#
#
#         var custom_icon_08d871f0628e220789d8cc9224ae574d = L.icon({&quot;iconSize&quot;: [30, 30], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;});
#         marker_4f051be6cf494c21591638fb422383e0.setIcon(custom_icon_08d871f0628e220789d8cc9224ae574d);
#
#
#         var popup_bffb8486eeeb384ae0cb2fe2d1501c54 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aa614eca20c46ca5d653a7a6f8408b10 = $(`&lt;div id=&quot;html_aa614eca20c46ca5d653a7a6f8408b10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bogotá&lt;/div&gt;`)[0];
#                 popup_bffb8486eeeb384ae0cb2fe2d1501c54.setContent(html_aa614eca20c46ca5d653a7a6f8408b10);
#
#
#
#         marker_4f051be6cf494c21591638fb422383e0.bindPopup(popup_bffb8486eeeb384ae0cb2fe2d1501c54)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# Crear un mapa centrado en una ubicación específica
mapa = folium.Map(location=[4.60971, -74.08175], zoom_start=10)

# Agregar marcadores en diferentes ubicaciones
folium.Marker([4.60971, -74.08175], popup='Bogotá').add_to(mapa)
folium.Marker([6.24420, -75.58120], popup='Medellín').add_to(mapa)

# Coordenadas de los puntos para trazar la línea
coordenadas_linea = [[4.60971, -74.08175], [6.24420, -75.58120]]

# Agregar la línea que conecta los dos puntos
folium.PolyLine(locations=coordenadas_linea, color='blue').add_to(mapa)

# Mostrar el mapa interactivo en el notebook
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a94f3c4fbcaa6969802205b87ced1ded {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a94f3c4fbcaa6969802205b87ced1ded&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a94f3c4fbcaa6969802205b87ced1ded = L.map(
#                 &quot;map_a94f3c4fbcaa6969802205b87ced1ded&quot;,
#                 {
#                     center: [4.60971, -74.08175],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3aca81976a265785c3a9d04c96527417 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a94f3c4fbcaa6969802205b87ced1ded);
#
#
#             var marker_04f77710de9a6e76a034be8d9241a679 = L.marker(
#                 [4.60971, -74.08175],
#                 {}
#             ).addTo(map_a94f3c4fbcaa6969802205b87ced1ded);
#
#
#         var popup_765c0097fd4c5adc2716c28e4a561cdc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7e5bda454a18e14438d98e48bd1f2579 = $(`&lt;div id=&quot;html_7e5bda454a18e14438d98e48bd1f2579&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bogotá&lt;/div&gt;`)[0];
#                 popup_765c0097fd4c5adc2716c28e4a561cdc.setContent(html_7e5bda454a18e14438d98e48bd1f2579);
#
#
#
#         marker_04f77710de9a6e76a034be8d9241a679.bindPopup(popup_765c0097fd4c5adc2716c28e4a561cdc)
#         ;
#
#
#
#
#             var marker_732d79dcfc9ba6cee40aff376af99055 = L.marker(
#                 [6.2442, -75.5812],
#                 {}
#             ).addTo(map_a94f3c4fbcaa6969802205b87ced1ded);
#
#
#         var popup_dd12c057f147cae64c38a03baac3e39f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b6218b54f36c528c6b3ba4bd754385ff = $(`&lt;div id=&quot;html_b6218b54f36c528c6b3ba4bd754385ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Medellín&lt;/div&gt;`)[0];
#                 popup_dd12c057f147cae64c38a03baac3e39f.setContent(html_b6218b54f36c528c6b3ba4bd754385ff);
#
#
#
#         marker_732d79dcfc9ba6cee40aff376af99055.bindPopup(popup_dd12c057f147cae64c38a03baac3e39f)
#         ;
#
#
#
#
#             var poly_line_ad31d1f0b67c342313dc7430b2d1d0c7 = L.polyline(
#                 [[4.60971, -74.08175], [6.2442, -75.5812]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a94f3c4fbcaa6969802205b87ced1ded);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
from geopy.distance import geodesic

# Crear un mapa centrado en una ubicación específica
mapa = folium.Map(location=[4.60971, -74.08175], zoom_start=6)

# Agregar marcadores en diferentes ubicaciones
bogota_coords = [4.60971, -74.08175]
medellin_coords = [6.24420, -75.58120]
folium.Marker(bogota_coords, popup='Bogotá').add_to(mapa)
folium.Marker(medellin_coords, popup='Medellín').add_to(mapa)

# Coordenadas de los puntos para trazar la línea
coordenadas_linea = [bogota_coords, medellin_coords]

# Agregar la línea que conecta los dos puntos
folium.PolyLine(locations=coordenadas_linea, color='blue').add_to(mapa)

# Calcular la distancia entre los dos puntos en kilómetros
distancia_km = geodesic(bogota_coords, medellin_coords).kilometers

# Agregar texto con la distancia en el punto medio de la línea
medio_linea = [(bogota_coords[0] + medellin_coords[0]) / 2, (bogota_coords[1] + medellin_coords[1]) / 2]

folium.Marker(location=medio_linea, icon=folium.DivIcon(html=f"<div =\"background-color:white\">{distancia_km:.2f} km</div>")).add_to(mapa)

# Mostrar el mapa interactivo en el notebook
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_57cf9802222addc64eb316fe6e775988 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_57cf9802222addc64eb316fe6e775988&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_57cf9802222addc64eb316fe6e775988 = L.map(
#                 &quot;map_57cf9802222addc64eb316fe6e775988&quot;,
#                 {
#                     center: [4.60971, -74.08175],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eb26225477212dac00ddbe65b10cff50 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_57cf9802222addc64eb316fe6e775988);
#
#
#             var marker_51ce83d57e8c2f6d9f64f8d2fdbb6bd3 = L.marker(
#                 [4.60971, -74.08175],
#                 {}
#             ).addTo(map_57cf9802222addc64eb316fe6e775988);
#
#
#         var popup_c84a38b33bf67f9f9130d2e684a6693c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4da225c18c442ce2c8094b0266975627 = $(`&lt;div id=&quot;html_4da225c18c442ce2c8094b0266975627&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bogotá&lt;/div&gt;`)[0];
#                 popup_c84a38b33bf67f9f9130d2e684a6693c.setContent(html_4da225c18c442ce2c8094b0266975627);
#
#
#
#         marker_51ce83d57e8c2f6d9f64f8d2fdbb6bd3.bindPopup(popup_c84a38b33bf67f9f9130d2e684a6693c)
#         ;
#
#
#
#
#             var marker_6c7ec660493962907d71959f6779b21d = L.marker(
#                 [6.2442, -75.5812],
#                 {}
#             ).addTo(map_57cf9802222addc64eb316fe6e775988);
#
#
#         var popup_0874d247c9b61af7eef0208a28e9f823 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_571553b1e4d3321a7f726d8954645a27 = $(`&lt;div id=&quot;html_571553b1e4d3321a7f726d8954645a27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Medellín&lt;/div&gt;`)[0];
#                 popup_0874d247c9b61af7eef0208a28e9f823.setContent(html_571553b1e4d3321a7f726d8954645a27);
#
#
#
#         marker_6c7ec660493962907d71959f6779b21d.bindPopup(popup_0874d247c9b61af7eef0208a28e9f823)
#         ;
#
#
#
#
#             var poly_line_f7809d71d2a5e533945fcc6f3cef54e6 = L.polyline(
#                 [[4.60971, -74.08175], [6.2442, -75.5812]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_57cf9802222addc64eb316fe6e775988);
#
#
#             var marker_b572941ffafb09209953d18b4d6ceaf8 = L.marker(
#                 [5.4269549999999995, -74.831475],
#                 {}
#             ).addTo(map_57cf9802222addc64eb316fe6e775988);
#
#
#             var div_icon_35a1c717add934feee564b4620174796 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv =\&quot;background-color:white\&quot;\u003e245.52 km\u003c/div\u003e&quot;});
#             marker_b572941ffafb09209953d18b4d6ceaf8.setIcon(div_icon_35a1c717add934feee564b4620174796);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
