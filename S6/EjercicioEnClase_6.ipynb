# %% [markdown]
# # Ejercicio en clase 6
#
# ##### Dataset de Peajes (Exploración, Limpieza, Combinación, visualización en mapa)
#
# https://www.kaggle.com/datasets/martinaltamar/historico-peajes-colombia-trafico-y-recaudo
#
# https://geoportal.dane.gov.co/servicios/descarga-y-metadatos/datos-geoestadisticos/?cod=4
#
#
# Usando la información de los siguientes enlaces:
#
# Dataset de Kaggle: Historico Peajes Colombia - Tráfico y Recaudo
# Datos Geoespaciales del DANE: Descarga y Metadatos - Datos Geoestadísticos de Colombia
#
# Tu tarea es crear un mapa interactivo donde se puedan visualizar los peajes registrados en Colombia. Utiliza los datos proporcionados en el dataset de Kaggle para obtener la información relevante sobre los peajes, como su ubicación geoespacial y otros atributos pertinentes. Luego, utiliza los datos geoespaciales del DANE para representar correctamente la geografía de Colombia en el mapa.
#
# Puedes hacer uso de la biblioteca Folium en Python para la visualización del mapa interactivo. Asegúrate de incluir marcadores para cada peaje con información relevante que permita a los usuarios explorar los detalles de cada ubicación de peaje.
#
# Además, considera utilizar colores o tamaños de marcadores para resaltar características específicas de los peajes, como la tarifa

# %% [markdown]
# ## Usando Folium

# %% [markdown]
# ##### 💡 Recuerde instalar la librería
#
# ### Referencias
#
# - https://github.com/python-visualization/folium
# - https://python-visualization.github.io/folium/
# - https://nbviewer.org/github/python-visualization/folium/tree/main/examples/

# %%
import pandas as pd
import folium

# Crear un DataFrame con las coordenadas geográficas de las ciudades principales de Colombia
data = {
    'City': ['Bogotá', 'Medellín', 'Cali', 'Barranquilla', 'Cartagena'],
    'Latitude': [4.6482837, 6.2518402, 3.42158, 10.963889, 10.39972],
    'Longitude': [-74.2478935, -75.5635918, -76.5205, -74.796389, -75.51444]
}
df = pd.DataFrame(data)

# Crear un mapa de Folium centrado en Colombia
m = folium.Map(location=[4.6482837, -74.2478935], zoom_start=6)

# Agregar marcadores para cada ciudad al mapa
for index, row in df.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=row['City'],
        icon=folium.Icon(icon='cloud')  # Puedes cambiar el icono aquí
    ).add_to(m)

# Mostrar el mapa
m.save('map_colombia_cities.html')  # Guardar el mapa en un archivo HTML

# m.show_in_browser()

# %% [markdown]
# # Mapa con marcadores:

# %%
import folium

# Crear un mapa centrado en una ubicación específica
mapa = folium.Map(location=[4.60971, -74.08175], zoom_start=10)

# Agregar marcadores en diferentes ubicaciones
folium.Marker([4.60971, -74.08175], popup='Bogotá').add_to(mapa)
folium.Marker([6.24420, -75.58120], popup='Medellín').add_to(mapa)
folium.Marker([10.39105, -75.47971], popup='Cartagena').add_to(mapa)

# Mostrar el mapa interactivo
mapa.save('mapa_marcadores.html')

# Mostrar el mapa interactivo en el notebook
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48e63dcc59e866bc9fb29a33a2a7c3ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48e63dcc59e866bc9fb29a33a2a7c3ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_48e63dcc59e866bc9fb29a33a2a7c3ce = L.map(
#                 &quot;map_48e63dcc59e866bc9fb29a33a2a7c3ce&quot;,
#                 {
#                     center: [4.60971, -74.08175],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_863100faffd01654222129d9aa222f98 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_48e63dcc59e866bc9fb29a33a2a7c3ce);
#
#
#             var marker_812cb9b3c93bc30202cd78e311d9ff03 = L.marker(
#                 [4.60971, -74.08175],
#                 {}
#             ).addTo(map_48e63dcc59e866bc9fb29a33a2a7c3ce);
#
#
#         var popup_c23dc5b880cdf9672c13a94b06184843 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d7ee50cf21e917ce2f69e5f65b356a28 = $(`&lt;div id=&quot;html_d7ee50cf21e917ce2f69e5f65b356a28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bogotá&lt;/div&gt;`)[0];
#                 popup_c23dc5b880cdf9672c13a94b06184843.setContent(html_d7ee50cf21e917ce2f69e5f65b356a28);
#
#
#
#         marker_812cb9b3c93bc30202cd78e311d9ff03.bindPopup(popup_c23dc5b880cdf9672c13a94b06184843)
#         ;
#
#
#
#
#             var marker_40f76a25a402a2a9c116cea585f9902b = L.marker(
#                 [6.2442, -75.5812],
#                 {}
#             ).addTo(map_48e63dcc59e866bc9fb29a33a2a7c3ce);
#
#
#         var popup_17d1717491c85da5a5874ee1983807d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e0d8ceeb6cfd10b02e273c72233488c7 = $(`&lt;div id=&quot;html_e0d8ceeb6cfd10b02e273c72233488c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Medellín&lt;/div&gt;`)[0];
#                 popup_17d1717491c85da5a5874ee1983807d8.setContent(html_e0d8ceeb6cfd10b02e273c72233488c7);
#
#
#
#         marker_40f76a25a402a2a9c116cea585f9902b.bindPopup(popup_17d1717491c85da5a5874ee1983807d8)
#         ;
#
#
#
#
#             var marker_70cfe9ed7b61661b6a3a9b17cfb1261f = L.marker(
#                 [10.39105, -75.47971],
#                 {}
#             ).addTo(map_48e63dcc59e866bc9fb29a33a2a7c3ce);
#
#
#         var popup_65272ccda7f51af465d314f198d2bc1c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ccbc42685d8d1d7fb47f996742fd411c = $(`&lt;div id=&quot;html_ccbc42685d8d1d7fb47f996742fd411c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cartagena&lt;/div&gt;`)[0];
#                 popup_65272ccda7f51af465d314f198d2bc1c.setContent(html_ccbc42685d8d1d7fb47f996742fd411c);
#
#
#
#         marker_70cfe9ed7b61661b6a3a9b17cfb1261f.bindPopup(popup_65272ccda7f51af465d314f198d2bc1c)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Mapa de calor:

# %%
import folium
from folium.plugins import HeatMap

# Crear un mapa centrado en una ubicación específica
mapa = folium.Map(location=[4.60971, -74.08175], zoom_start=10)

# Datos de ejemplo con ubicaciones y pesos
datos = [[4.60971, -74.08175, 10], [6.24420, -75.58120, 5], [10.39105, -75.47971, 15]]

# Agregar el mapa de calor con los datos
HeatMap(datos).add_to(mapa)

# Mostrar el mapa interactivo
mapa.save('mapa_calor.html')

# Mostrar el mapa interactivo en el notebook
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d73d744259ce26bb37c0cfdac07c3b3b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d73d744259ce26bb37c0cfdac07c3b3b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d73d744259ce26bb37c0cfdac07c3b3b = L.map(
#                 &quot;map_d73d744259ce26bb37c0cfdac07c3b3b&quot;,
#                 {
#                     center: [4.60971, -74.08175],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_159eb9c38996595981517826c545e4fe = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d73d744259ce26bb37c0cfdac07c3b3b);
#
#
#             var heat_map_a8aa3436dfefb1c91d7b1d4108169c0d = L.heatLayer(
#                 [[4.60971, -74.08175, 10], [6.2442, -75.5812, 5], [10.39105, -75.47971, 15]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 25}
#             ).addTo(map_d73d744259ce26bb37c0cfdac07c3b3b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Mapa con polígonos:

# %%
import folium

# Crear un mapa centrado en una ubicación específica
mapa = folium.Map(location=[4.60971, -74.08175], zoom_start=10)

# Datos de ejemplo con coordenadas de los vértices de un polígono
vertices = [[4.5, -74.0], [4.7, -74.0], [4.7, -73.8], [4.5, -73.8]]

# Agregar un polígono al mapa
folium.Polygon(locations=vertices, color='blue', fill=True, fill_color='blue').add_to(mapa)

# Mostrar el mapa interactivo
mapa.save('mapa_poligono.html')

# Mostrar el mapa interactivo en el notebook
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_117794bd225f8c54996e075b8e0dffb2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_117794bd225f8c54996e075b8e0dffb2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_117794bd225f8c54996e075b8e0dffb2 = L.map(
#                 &quot;map_117794bd225f8c54996e075b8e0dffb2&quot;,
#                 {
#                     center: [4.60971, -74.08175],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e8195ce07792f90ac7962f8f0e693fda = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_117794bd225f8c54996e075b8e0dffb2);
#
#
#             var polygon_1474793debbf5f6cc789573efcfeef0f = L.polygon(
#                 [[4.5, -74.0], [4.7, -74.0], [4.7, -73.8], [4.5, -73.8]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_117794bd225f8c54996e075b8e0dffb2);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# Crear un mapa centrado en una ubicación específica
mapa = folium.Map(location=[4.60971, -74.08175], zoom_start=10)

# Agregar marcadores en diferentes ubicaciones con contenido personalizado para el popup
folium.Marker([4.60971, -74.08175], popup='Bogotá - Capital de Colombia').add_to(mapa)
folium.Marker([6.24420, -75.58120], popup='Medellín - Ciudad de la eterna primavera').add_to(mapa)
folium.Marker([10.39105, -75.47971], popup='Cartagena - Ciudad amurallada').add_to(mapa)

# Mostrar el mapa interactivo en el notebook
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_afa027ac18ab5cb4a24fe5b4af7bdb20 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_afa027ac18ab5cb4a24fe5b4af7bdb20&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_afa027ac18ab5cb4a24fe5b4af7bdb20 = L.map(
#                 &quot;map_afa027ac18ab5cb4a24fe5b4af7bdb20&quot;,
#                 {
#                     center: [4.60971, -74.08175],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4396dbb7f50e14e942f2419b0286579c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_afa027ac18ab5cb4a24fe5b4af7bdb20);
#
#
#             var marker_2bc9c78f6aae1f0a6c06a98d79a635cd = L.marker(
#                 [4.60971, -74.08175],
#                 {}
#             ).addTo(map_afa027ac18ab5cb4a24fe5b4af7bdb20);
#
#
#         var popup_28586622adf800735bfe63d4d879fa32 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5ee67d0c3e762afa373e9a393aeca09c = $(`&lt;div id=&quot;html_5ee67d0c3e762afa373e9a393aeca09c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bogotá - Capital de Colombia&lt;/div&gt;`)[0];
#                 popup_28586622adf800735bfe63d4d879fa32.setContent(html_5ee67d0c3e762afa373e9a393aeca09c);
#
#
#
#         marker_2bc9c78f6aae1f0a6c06a98d79a635cd.bindPopup(popup_28586622adf800735bfe63d4d879fa32)
#         ;
#
#
#
#
#             var marker_2c44cbb089c04caad7134037778b59c8 = L.marker(
#                 [6.2442, -75.5812],
#                 {}
#             ).addTo(map_afa027ac18ab5cb4a24fe5b4af7bdb20);
#
#
#         var popup_b7afd029754eca394243c9155de65ed1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c3a064dbc1f711b5eb4d9d3de23a2e93 = $(`&lt;div id=&quot;html_c3a064dbc1f711b5eb4d9d3de23a2e93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Medellín - Ciudad de la eterna primavera&lt;/div&gt;`)[0];
#                 popup_b7afd029754eca394243c9155de65ed1.setContent(html_c3a064dbc1f711b5eb4d9d3de23a2e93);
#
#
#
#         marker_2c44cbb089c04caad7134037778b59c8.bindPopup(popup_b7afd029754eca394243c9155de65ed1)
#         ;
#
#
#
#
#             var marker_b67bc273014533a6abcc9a1b661d44f7 = L.marker(
#                 [10.39105, -75.47971],
#                 {}
#             ).addTo(map_afa027ac18ab5cb4a24fe5b4af7bdb20);
#
#
#         var popup_e3754e19faf710676530e9d5b79f7f81 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d838b688751ddebad4834633117f6975 = $(`&lt;div id=&quot;html_d838b688751ddebad4834633117f6975&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cartagena - Ciudad amurallada&lt;/div&gt;`)[0];
#                 popup_e3754e19faf710676530e9d5b79f7f81.setContent(html_d838b688751ddebad4834633117f6975);
#
#
#
#         marker_b67bc273014533a6abcc9a1b661d44f7.bindPopup(popup_e3754e19faf710676530e9d5b79f7f81)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# Crear un mapa centrado en una ubicación específica
mapa = folium.Map(location=[4.60971, -74.08175], zoom_start=10)

# Agregar un marcador con un icono predefinido (en este caso, un ícono de estrella)
folium.Marker([4.60971, -74.08175], popup='Bogotá', icon=folium.Icon(icon='star')).add_to(mapa)

# Mostrar el mapa interactivo en el notebook
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dea1c4b8f53b3f94fd3cf24ff758cbdd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dea1c4b8f53b3f94fd3cf24ff758cbdd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dea1c4b8f53b3f94fd3cf24ff758cbdd = L.map(
#                 &quot;map_dea1c4b8f53b3f94fd3cf24ff758cbdd&quot;,
#                 {
#                     center: [4.60971, -74.08175],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e58a2bc2f490c2266c19684f3edecd9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_dea1c4b8f53b3f94fd3cf24ff758cbdd);
#
#
#             var marker_fd7e7a591805493484cece3b91943cbf = L.marker(
#                 [4.60971, -74.08175],
#                 {}
#             ).addTo(map_dea1c4b8f53b3f94fd3cf24ff758cbdd);
#
#
#             var icon_439f061133d44fe85bbc14cfa5faa851 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fd7e7a591805493484cece3b91943cbf.setIcon(icon_439f061133d44fe85bbc14cfa5faa851);
#
#
#         var popup_4d1f3150b91c9c3f54c7e6f2ade31fbe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_83e54f741db7b1203b1d7e4d77326c08 = $(`&lt;div id=&quot;html_83e54f741db7b1203b1d7e4d77326c08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bogotá&lt;/div&gt;`)[0];
#                 popup_4d1f3150b91c9c3f54c7e6f2ade31fbe.setContent(html_83e54f741db7b1203b1d7e4d77326c08);
#
#
#
#         marker_fd7e7a591805493484cece3b91943cbf.bindPopup(popup_4d1f3150b91c9c3f54c7e6f2ade31fbe)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# Crear un mapa centrado en una ubicación específica
mapa = folium.Map(location=[4.60971, -74.08175], zoom_start=10)

# Definir la ruta del archivo de imagen del icono personalizado
ruta_icono_personalizado = 'dolar.png'

# Crear un objeto Icon con el icono personalizado
icono_personalizado = folium.CustomIcon(icon_image=ruta_icono_personalizado, icon_size=(30, 30))

# Agregar un marcador con el icono personalizado
folium.Marker([4.60971, -74.08175], popup='Bogotá', icon=icono_personalizado).add_to(mapa)

# Mostrar el mapa interactivo en el notebook
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_42704f22177695e79653570282cfe1b3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_42704f22177695e79653570282cfe1b3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_42704f22177695e79653570282cfe1b3 = L.map(
#                 &quot;map_42704f22177695e79653570282cfe1b3&quot;,
#                 {
#                     center: [4.60971, -74.08175],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_385ad37f0ab45821ca197ec4349691ca = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_42704f22177695e79653570282cfe1b3);
#
#
#             var marker_d30e479be496029fc4b9591675e16774 = L.marker(
#                 [4.60971, -74.08175],
#                 {}
#             ).addTo(map_42704f22177695e79653570282cfe1b3);
#
#
#         var custom_icon_4e8ff99681831ba98fa3ed599495041c = L.icon({&quot;iconSize&quot;: [30, 30], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;});
#         marker_d30e479be496029fc4b9591675e16774.setIcon(custom_icon_4e8ff99681831ba98fa3ed599495041c);
#
#
#         var popup_497c44edb14c91e09357b0e10847327f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a730111a804d1cbf00b4335ccdbead85 = $(`&lt;div id=&quot;html_a730111a804d1cbf00b4335ccdbead85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bogotá&lt;/div&gt;`)[0];
#                 popup_497c44edb14c91e09357b0e10847327f.setContent(html_a730111a804d1cbf00b4335ccdbead85);
#
#
#
#         marker_d30e479be496029fc4b9591675e16774.bindPopup(popup_497c44edb14c91e09357b0e10847327f)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# Crear un mapa centrado en una ubicación específica
mapa = folium.Map(location=[4.60971, -74.08175], zoom_start=10)

# Agregar marcadores en diferentes ubicaciones
folium.Marker([4.60971, -74.08175], popup='Bogotá').add_to(mapa)
folium.Marker([6.24420, -75.58120], popup='Medellín').add_to(mapa)

# Coordenadas de los puntos para trazar la línea
coordenadas_linea = [[4.60971, -74.08175], [6.24420, -75.58120]]

# Agregar la línea que conecta los dos puntos
folium.PolyLine(locations=coordenadas_linea, color='blue').add_to(mapa)

# Mostrar el mapa interactivo en el notebook
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b1fbb5b2a5022e951cf4e752d799aec0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b1fbb5b2a5022e951cf4e752d799aec0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b1fbb5b2a5022e951cf4e752d799aec0 = L.map(
#                 &quot;map_b1fbb5b2a5022e951cf4e752d799aec0&quot;,
#                 {
#                     center: [4.60971, -74.08175],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c6c2b73a3a1f40c054a6d2a1ffcf8c34 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b1fbb5b2a5022e951cf4e752d799aec0);
#
#
#             var marker_d891cf7174f0efbcf7eb4e28faefbf6f = L.marker(
#                 [4.60971, -74.08175],
#                 {}
#             ).addTo(map_b1fbb5b2a5022e951cf4e752d799aec0);
#
#
#         var popup_289dabcb70d6c26a5df895e8cedc45a7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3adba3add91bce47f837c3acbb3a22d1 = $(`&lt;div id=&quot;html_3adba3add91bce47f837c3acbb3a22d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bogotá&lt;/div&gt;`)[0];
#                 popup_289dabcb70d6c26a5df895e8cedc45a7.setContent(html_3adba3add91bce47f837c3acbb3a22d1);
#
#
#
#         marker_d891cf7174f0efbcf7eb4e28faefbf6f.bindPopup(popup_289dabcb70d6c26a5df895e8cedc45a7)
#         ;
#
#
#
#
#             var marker_20188c9377efcc601c5a0bba0d2a445a = L.marker(
#                 [6.2442, -75.5812],
#                 {}
#             ).addTo(map_b1fbb5b2a5022e951cf4e752d799aec0);
#
#
#         var popup_e19b4b4cb7f5455ef1a46f7d4e0c4892 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_914f619166ee2ea2e36948d4bebd7cfa = $(`&lt;div id=&quot;html_914f619166ee2ea2e36948d4bebd7cfa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Medellín&lt;/div&gt;`)[0];
#                 popup_e19b4b4cb7f5455ef1a46f7d4e0c4892.setContent(html_914f619166ee2ea2e36948d4bebd7cfa);
#
#
#
#         marker_20188c9377efcc601c5a0bba0d2a445a.bindPopup(popup_e19b4b4cb7f5455ef1a46f7d4e0c4892)
#         ;
#
#
#
#
#             var poly_line_8df7e3220b481be7c564ffb4c89ee207 = L.polyline(
#                 [[4.60971, -74.08175], [6.2442, -75.5812]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b1fbb5b2a5022e951cf4e752d799aec0);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
from geopy.distance import geodesic

# Crear un mapa centrado en una ubicación específica
mapa = folium.Map(location=[4.60971, -74.08175], zoom_start=6)

# Agregar marcadores en diferentes ubicaciones
bogota_coords = [4.60971, -74.08175]
medellin_coords = [6.24420, -75.58120]
folium.Marker(bogota_coords, popup='Bogotá').add_to(mapa)
folium.Marker(medellin_coords, popup='Medellín').add_to(mapa)

# Coordenadas de los puntos para trazar la línea
coordenadas_linea = [bogota_coords, medellin_coords]

# Agregar la línea que conecta los dos puntos
folium.PolyLine(locations=coordenadas_linea, color='blue').add_to(mapa)

# Calcular la distancia entre los dos puntos en kilómetros
distancia_km = geodesic(bogota_coords, medellin_coords).kilometers

# Agregar texto con la distancia en el punto medio de la línea
medio_linea = [(bogota_coords[0] + medellin_coords[0]) / 2, (bogota_coords[1] + medellin_coords[1]) / 2]

folium.Marker(location=medio_linea, icon=folium.DivIcon(html=f"<div =\"background-color:white\">{distancia_km:.2f} km</div>")).add_to(mapa)

# Mostrar el mapa interactivo en el notebook
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3fb37a28063ae9c8fcf458ce29818eb9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3fb37a28063ae9c8fcf458ce29818eb9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3fb37a28063ae9c8fcf458ce29818eb9 = L.map(
#                 &quot;map_3fb37a28063ae9c8fcf458ce29818eb9&quot;,
#                 {
#                     center: [4.60971, -74.08175],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_af0d5e4133af758e5aad7df683a87b8d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3fb37a28063ae9c8fcf458ce29818eb9);
#
#
#             var marker_ef6e52d17bc90be75147de49a6549a23 = L.marker(
#                 [4.60971, -74.08175],
#                 {}
#             ).addTo(map_3fb37a28063ae9c8fcf458ce29818eb9);
#
#
#         var popup_6bd9232e8a91354ef2bc41989cdd6c29 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d5bd355750c37761abe3623879324f8d = $(`&lt;div id=&quot;html_d5bd355750c37761abe3623879324f8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bogotá&lt;/div&gt;`)[0];
#                 popup_6bd9232e8a91354ef2bc41989cdd6c29.setContent(html_d5bd355750c37761abe3623879324f8d);
#
#
#
#         marker_ef6e52d17bc90be75147de49a6549a23.bindPopup(popup_6bd9232e8a91354ef2bc41989cdd6c29)
#         ;
#
#
#
#
#             var marker_78a489b01a1a98ad777b4b1ba1bdc87b = L.marker(
#                 [6.2442, -75.5812],
#                 {}
#             ).addTo(map_3fb37a28063ae9c8fcf458ce29818eb9);
#
#
#         var popup_2625d8be8db4cd61297282f5b2bac34a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_24d3a8a20067dd457ea960ec4fc1e441 = $(`&lt;div id=&quot;html_24d3a8a20067dd457ea960ec4fc1e441&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Medellín&lt;/div&gt;`)[0];
#                 popup_2625d8be8db4cd61297282f5b2bac34a.setContent(html_24d3a8a20067dd457ea960ec4fc1e441);
#
#
#
#         marker_78a489b01a1a98ad777b4b1ba1bdc87b.bindPopup(popup_2625d8be8db4cd61297282f5b2bac34a)
#         ;
#
#
#
#
#             var poly_line_2237da50d02d2ca2422a4b194c07aaf9 = L.polyline(
#                 [[4.60971, -74.08175], [6.2442, -75.5812]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3fb37a28063ae9c8fcf458ce29818eb9);
#
#
#             var marker_2c650a173c9b199c5419201d1ce1c512 = L.marker(
#                 [5.4269549999999995, -74.831475],
#                 {}
#             ).addTo(map_3fb37a28063ae9c8fcf458ce29818eb9);
#
#
#             var div_icon_13ea579ff91a64be966b3344367aac06 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv =\&quot;background-color:white\&quot;\u003e245.52 km\u003c/div\u003e&quot;});
#             marker_2c650a173c9b199c5419201d1ce1c512.setIcon(div_icon_13ea579ff91a64be966b3344367aac06);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
